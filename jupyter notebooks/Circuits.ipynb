# %% [markdown]
# ### Importing libraries

# %%
import folium
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import json
import requests
import seaborn as sns
sns.set()

# %% [markdown]
# ### F1 API (Circuits) and Dataframe creation

# %%
url = f'http://ergast.com/api/f1/circuits.json?offset=0&limit=999'
response = requests.get(url).json()

circuits = response['MRData']['CircuitTable']['Circuits']

df = pd.json_normalize(circuits)
df = df.dropna(axis=1)
df.rename(columns = {'Location.lat':'Latitude', 'Location.long':'Longitude', 'Location.locality':'Locality',
                              'Location.country':'Country'}, inplace = True)

def combine_to_array(row):
    return [float(row['Latitude']), float(row['Longitude'])]
df['Location'] = df.apply(combine_to_array, axis=1)

df
# Out:
#       circuitId                                                url  \
# 0      adelaide  http://en.wikipedia.org/wiki/Adelaide_Street_C...
# 1      ain-diab      http://en.wikipedia.org/wiki/Ain-Diab_Circuit
# 2       aintree  http://en.wikipedia.org/wiki/Aintree_Motor_Rac...
# 3   albert_park  http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 4      americas  http://en.wikipedia.org/wiki/Circuit_of_the_Am...
# ..          ...                                                ...
# 72   yas_marina    http://en.wikipedia.org/wiki/Yas_Marina_Circuit
# 73      yeongam  http://en.wikipedia.org/wiki/Korean_Internatio...
# 74    zandvoort     http://en.wikipedia.org/wiki/Circuit_Zandvoort
# 75      zeltweg      http://en.wikipedia.org/wiki/Zeltweg_Airfield
# 76       zolder                http://en.wikipedia.org/wiki/Zolder
#
#                        circuitName  Latitude Longitude        Locality  \
# 0          Adelaide Street Circuit  -34.9272   138.617        Adelaide
# 1                         Ain Diab   33.5786   -7.6875      Casablanca
# 2                          Aintree   53.4769  -2.94056       Liverpool
# 3   Albert Park Grand Prix Circuit  -37.8497   144.968       Melbourne
# 4          Circuit of the Americas   30.1328  -97.6411          Austin
# ..                             ...       ...       ...             ...
# 72              Yas Marina Circuit   24.4672   54.6031       Abu Dhabi
# 73    Korean International Circuit   34.7333   126.417  Yeongam County
# 74          Circuit Park Zandvoort   52.3888   4.54092       Zandvoort
# 75                         Zeltweg   47.2039   14.7478          Styria
# 76                          Zolder   50.9894   5.25694  Heusden-Zolder
#
#         Country             Location
# 0     Australia  [-34.9272, 138.617]
# 1       Morocco   [33.5786, -7.6875]
# 2            UK  [53.4769, -2.94056]
# 3     Australia  [-37.8497, 144.968]
# 4           USA  [30.1328, -97.6411]
# ..          ...                  ...
# 72          UAE   [24.4672, 54.6031]
# 73        Korea   [34.7333, 126.417]
# 74  Netherlands   [52.3888, 4.54092]
# 75      Austria   [47.2039, 14.7478]
# 76      Belgium   [50.9894, 5.25694]
#
# [77 rows x 8 columns]

# %% [markdown]
# ### Converting latitudes and longitudes into a 2D list

# %%
points = df['Location'].tolist()
# Out:
# [[-34.9272, 138.617],
#  [33.5786, -7.6875],
#  [53.4769, -2.94056],
#  [-37.8497, 144.968],
#  [30.1328, -97.6411],
#  [57.2653, 13.6042],
#  [52.4806, 13.2514],
#  [26.0325, 50.5106],
#  [40.3725, 49.8533],
#  [41.1705, -8.67325],
#  [51.3569, 0.263056],
#  [46.9589, 7.40194],
#  [28.3487, 77.5331],
#  [41.57, 2.26111],
#  [45.7472, 3.03889],
#  [32.7774, -96.7587],
#  [42.3298, -83.0401],
#  [47.3625, 4.89913],
#  [52.8306, -1.37528],
#  [49.3306, 1.00458],
#  [38.7506, -9.39417],
#  [35.3717, 138.927],
#  [-34.6943, -58.4593],
#  [-33.0486, 27.8736],
#  [49.3278, 8.56583],
#  [47.5789, 19.2486],
#  [44.3439, 11.7167],
#  [39.795, -86.2347],
#  [-23.7036, -46.6997],
#  [40.9517, 29.405],
#  [-22.9756, -43.395],
#  [40.6171, -3.58558],
#  [21.6319, 39.1044],
#  [36.7083, -6.03417],
#  [-25.9894, 28.0767],
#  [36.1162, -115.174],
#  [47.95, 0.224231],
#  [33.7651, -118.189],
#  [25.49, 51.4542],
#  [46.8642, 3.16361],
#  [1.2914, 103.864],
#  [25.9581, -80.2389],
#  [43.7347, 7.42056],
#  [38.7197, -9.20306],
#  [41.3664, 2.15167],
#  [45.6156, 9.28111],
#  [44.0481, -78.6756],
#  [43.9975, 11.3719],
#  [50.6211, 4.32694],
#  [50.3356, 6.9475],
#  [34.915, 134.221],
#  [41.3903, 2.11667],
#  [42.475, 14.1508],
#  [33.4479, -112.075],
#  [37.227, -8.6267],
#  [47.2197, 14.7647],
#  [49.2542, 3.93083],
#  [43.2506, 5.79167],
#  [33.937, -117.273],
#  [19.4042, -99.0907],
#  [27.4547, -81.3483],
#  [2.76083, 101.738],
#  [31.3389, 121.22],
#  [52.0786, -1.01694],
#  [43.4057, 39.9578],
#  [50.4372, 5.97139],
#  [34.8431, 136.541],
#  [46.1877, -74.6099],
#  [39.4589, -0.331667],
#  [36.1147, -115.173],
#  [45.5, -73.5228],
#  [42.3369, -76.9272],
#  [24.4672, 54.6031],
#  [34.7333, 126.417],
#  [52.3888, 4.54092],
#  [47.2039, 14.7478],
#  [50.9894, 5.25694]]

# %% [markdown]
# ### Creating map with location and circuit name

# %%
map = folium.Map(location=[21.6319,39.1044], zoom_start=2)
for i in range(len(points)):
    folium.Marker(points[i], popup=df['circuitName'][i]).add_to(map)

title = '''
             <h3 align="center" style="font-size:16px"><b>{}</b></h3>
        '''.format('All Race Circuits till date (Click to expand - scroll to zoom in/out)')     
map.get_root().html.add_child(folium.Element(title))
plt.show()

# %% [markdown]
# ###

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8e5097a11c71baed693e94cf4a65ef65 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#              &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;All Race Circuits till date (Click to expand - scroll to zoom in/out)&lt;/b&gt;&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8e5097a11c71baed693e94cf4a65ef65&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8e5097a11c71baed693e94cf4a65ef65 = L.map(
#                 &quot;map_8e5097a11c71baed693e94cf4a65ef65&quot;,
#                 {
#                     center: [21.6319, 39.1044],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6d3c1d860c39db1a865a35d3f0d28481 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6d3c1d860c39db1a865a35d3f0d28481.addTo(map_8e5097a11c71baed693e94cf4a65ef65);
#
#
#             var marker_7366190f169f725a4a330a129b343822 = L.marker(
#                 [-34.9272, 138.617],
#                 {}
#             ).addTo(map_8e5097a11c71baed693e94cf4a65ef65);
#
#
#         var popup_641680fc4f353389ee67dba1a58a732b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9e4cdca8bbedba10e7d08c3936d32049 = $(`&lt;div id=&quot;html_9e4cdca8bbedba10e7d08c3936d32049&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Adelaide Street Circuit&lt;/div&gt;`)[0];
#                 popup_641680fc4f353389ee67dba1a58a732b.setContent(html_9e4cdca8bbedba10e7d08c3936d32049);
#
#
#
#         marker_7366190f169f725a4a330a129b343822.bindPopup(popup_641680fc4f353389ee67dba1a58a732b)
#         ;
#
#
#
#
#             var marker_498701104efa2d4f52bf101b7bcb984d = L.marker(
#                 [33.5786, -7.6875],
#                 {}
#             ).addTo(map_8e5097a11c71baed693e94cf4a65ef65);
#
#
#         var popup_c828f2dfbecc13818de5b5c2d1e17155 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5e5b510f6ae03338211389bcc1eb66fd = $(`&lt;div id=&quot;html_5e5b510f6ae03338211389bcc1eb66fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ain Diab&lt;/div&gt;`)[0];
#                 popup_c828f2dfbecc13818de5b5c2d1e17155.setContent(html_5e5b510f6ae03338211389bcc1eb66fd);
#
#
#
#         marker_498701104efa2d4f52bf101b7bcb984d.bindPopup(popup_c828f2dfbecc13818de5b5c2d1e17155)
#         ;
#
#
#
#
#             var marker_3396563a9b35f7aba4b324be01d40d2f = L.marker(
#                 [53.4769, -2.94056],
#                 {}
#             ).addTo(map_8e5097a11c71baed693e94cf4a65ef65);
#
#
#         var popup_80ab2bfb22f4eb06ae07445881435030 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c1ceeeaf6515739092d2dbfac0d50bb8 = $(`&lt;div id=&quot;html_c1ceeeaf6515739092d2dbfac0d50bb8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Aintree&lt;/div&gt;`)[0];
#                 popup_80ab2bfb22f4eb06ae07445881435030.setContent(html_c1ceeeaf6515739092d2dbfac0d50bb8);
#
#
#
#         marker_3396563a9b35f7aba4b324be01d40d2f.bindPopup(popup_80ab2bfb22f4eb06ae07445881435030)
#         ;
#
#
#
#
#             var marker_a26b63df7b28e51e440185f157484c05 = L.marker(
#                 [-37.8497, 144.968],
#                 {}
#             ).addTo(map_8e5097a11c71baed693e94cf4a65ef65);
#
#
#         var popup_211933938e124514556ae5908ae60a83 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e849835c6db001eb733287da7b157b05 = $(`&lt;div id=&quot;html_e849835c6db001eb733287da7b157b05&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Albert Park Grand Prix Circuit&lt;/div&gt;`)[0];
#                 popup_211933938e124514556ae5908ae60a83.setContent(html_e849835c6db001eb733287da7b157b05);
#
#
#
#         marker_a26b63df7b28e51e440185f157484c05.bindPopup(popup_211933938e124514556ae5908ae60a83)
#         ;
#
#
#
#
#             var marker_fc6bbf4cf42a9cf38757a41e9eda644a = L.marker(
#                 [30.1328, -97.6411],
#                 {}
#             ).addTo(map_8e5097a11c71baed693e94cf4a65ef65);
#
#
#         var popup_192c63151b1f7dd5bf839406addb2a94 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6d691776c86800a475389711f2ef999a = $(`&lt;div id=&quot;html_6d691776c86800a475389711f2ef999a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Circuit of the Americas&lt;/div&gt;`)[0];
#                 popup_192c63151b1f7dd5bf839406addb2a94.setContent(html_6d691776c86800a475389711f2ef999a);
#
#
#
#         marker_fc6bbf4cf42a9cf38757a41e9eda644a.bindPopup(popup_192c63151b1f7dd5bf839406addb2a94)
#         ;
